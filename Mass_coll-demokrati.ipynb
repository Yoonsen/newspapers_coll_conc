# %% [markdown]
# # Data and computations for paper
#
# Lars G. Johnsen
# National Library of Norway

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
mu.update('collocations')
from collocations import dist_coll_urn
import pandas as pd
# Out:
# Updated file `D:\documents\GitHub\newspapers_coll_conc\collocations.py`

# %%
def df_jaccard(df, col1, col2, number=100, asc=False):
    s1 = df.sort_values(by=col1, ascending=asc)[:number].index
    s2 = df.sort_values(by=col2, ascending=asc)[:number].index
    
    #print(len(set(s1)&set(s2)))
    
    return jaccard(s1, s2)

# %%
def jaccard(s1, s2):
    return len(set(s1)&set(s2))/len(set(s1)|set(s2))

# %%
def make_coll_df(small, large, tot):
    """take two collocations, small and large, and a reference tot. The reference must av a column call tot as well"""
    coll = pd.DataFrame()
    coll['small'] = small['freq']
    coll['large'] = large['freq']
    #coll['ratio'] = coll['small']/coll['large']
    coll['srel'] = coll.small/coll.small.sum()
    coll['lrel'] = coll.large/coll.large.sum()
    coll['ratio'] = coll.srel/coll.lrel
    coll['nb'] = coll.small/tot.tot
    return coll

# %% [markdown]
# ### Reference corpus
#
# The reference is the total counts from approximately 450 000 books from nb.no

# %%
tot = nb.frame(nb.totals(50000), 'tot')

# %%
nb.normalize_corpus_dataframe(tot)
tot.head()
# Out:
#           tot
# .    0.058921
# ,    0.051453
# og   0.025297
# i    0.021425
# det  0.012728

# %% [markdown]
# # Corpus
#
# The corpus for doing collocations is a sample of 800 books from fictional literature, dewey decimal code 813.

# %%
corpus = nb.book_corpus(ddk="813%", period=(1980, 2000), limit = 5000)

# %%
corpus
# Out:
#                 urn               author  \
# 0     2010041503037   Snelling, Lauraine
# 1     2009021004144         Zach, Cheryl
# 2     2011021808094     Boswell, Barbara
# 3     2010040603082     Thomas, Jerry D.
# 4     2010070208014          Clancy, Tom
# ...             ...                  ...
# 4995  2015072308195       Dreyer, Eileen
# 4996  2008073104060         Hart, Alison
# 4997  2013010708129         Seger, Maura
# 4998  2008090100042         Turow, Scott
# 4999  2009042400041  Clark, Mary Higgins
#
#                                              title  year
# 0                                  DL på flyttefot  1999
# 1                                      Tause tårer  2000
# 2                                 Forførende blikk  1996
# 3     Slangestien -og andre spennende fortellinger  1999
# 4                                        Rainbow 6  1999
# ...                                            ...   ...
# 4995                                  Ut av mørket  1993
# 4996                             Ta tøylene, Sara!  1996
# 4997                                Nattens kvinne  1995
# 4998                            Blomsterbarnas arv  1999
# 4999                                    Sluttspill  1997
#
# [5000 rows x 4 columns]

# %% [markdown]
# Set up the distance parameters and collword, smd is small distance while lmd is large distance. These values are half of the actual window, and used to make a normalized score, call ascore. See below.

# %%
smd = 5
lmd = 10
collword = 'demokrati'

# %%
def large_corpus_coll(collword, urns = None, after= 5, before = 5, n = 300):
    colls = []
    for i in range(0, len(urns), n):
        colls.append(nb.urn_coll(collword, urns=urns[i:i + n], after= after, before = before))
    coll = pd.concat(colls, axis=1, sort=False).sum(axis=1)
    return pd.DataFrame(coll)

# %%
a1 = nb.frame(large_corpus_coll(collword, urns=list(corpus.urn), after= int(2*smd), before = 0), 'freq')
a2 = nb.frame(large_corpus_coll(collword, urns=list(corpus.urn), after= int(2*lmd), before = 0), 'freq')

# %%
b1 = nb.frame(large_corpus_coll(collword, urns=list(corpus.urn), after=0, before = int(2*smd)), 'freq')
b2 = nb.frame(large_corpus_coll(collword, urns=list(corpus.urn), after=0, before = int(2*lmd)), 'freq')

# %% [markdown]
# ## Create collocation dataframe
#
# Based on data from a1 and a2, and b1 and b2. The name for the collocations after is `coll` while `collb` is for the collocates coming before.

# %%
coll = make_coll_df(a1, a2, tot)
collb = make_coll_df(b1, b2, tot)

# %% [markdown]
# ## Sorting
#
# Sorting on the reference is by column 'nb'

# %%
collb[collb.small > 1].sort_values(by='ratio', ascending=False)[:20][:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row1_col5 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row2_col5 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row3_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row3_col5 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row4_col0 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row4_col1 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row4_col2 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row4_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T
{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e1a2a38_8df8_11ea_a308_000acd2bfab2row9_col5 {
#             background-color:  #ece7f2;
#             color:  #000000;

# %%
coll[coll.small < coll.large].sort_values(by='ratio', ascending=False)[:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row0_col0 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row0_col1 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row0_col2 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row0_col3 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row1_col0 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row1_col1 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row1_col2 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row1_col3 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row1_col4 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row1_col5 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row2_col0 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row2_col1 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row2_col2 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row2_col3 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row2_col4 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row2_col5 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row7_col5 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row8_col0 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row8_col1 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row8_col2 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row8_col3 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row8_col4 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row8_col5 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row9_col0 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row9_col1 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row9_col2 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row9_col3 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row9_col4 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_4a153b76_8df2_11ea_bf99_000acd2bfab2row9_col5 {
#             background-color:  #fbf3f9;
#             color:  #000000;

# %% [markdown]
# # collb

# %%
collb[collb.small < collb.large].sort_values(by='ratio', ascending=False)[:40].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_416df4ae_8df8_11ea_9339_000acd2bfab2row0_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row0_col1 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row0_col2 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row0_col3 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row0_col5 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row1_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row1_col1 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row1_col2 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row1_col3 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row1_col4 {
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row1_col5 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row2_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row2_col1 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row2_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row2_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row2_col4 {
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row2_col5 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row3_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row3_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row3_col2 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row3_col3 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row3_col4 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row3_col5 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row4_col0 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row4_col1 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row4_col2 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row4_col3 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row4_col4 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row4_col5 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row5_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row5_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row5_col2 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row5_col3 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row5_col4 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row5_col5 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row6_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row6_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row6_col2 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row6_col3 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row6_col4 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row6_col5 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row7_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row7_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row7_col2 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row7_col3 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row7_col4 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row7_col5 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row8_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row8_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row8_col2 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row8_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row8_col4 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row8_col5 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row9_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row9_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row9_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row9_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row9_col4 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_416df4ae_8df8_11ea_9339_000acd2bfab2row9_col5 {
#             background-color:  #fbf3f9;
#             color:  #000000;

# %%
collb.sort_values(by='nb', ascending=False)[:40].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row0_col1 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row0_col3 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row1_col0 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row1_col1 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row1_col2 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row1_col3 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row1_col5 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row2_col0 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row2_col1 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row2_col2 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row2_col3 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row2_col4 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row2_col5 {
#             background-color:  #88b1d4;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row3_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row3_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row3_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row3_col3 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row3_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row3_col5 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row4_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row4_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row4_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row4_col3 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row4_col5 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row5_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row5_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row5_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row5_col3 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row5_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row5_col5 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row6_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row6_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row6_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row6_col3 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row6_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row6_col5 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row7_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row7_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row7_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row7_col3 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row7_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row7_col5 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row8_col0 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row8_col1 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row8_col2 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row8_col3 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row8_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row8_col5 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row9_col0 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row9_col1 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row9_col2 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row9_col3 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row9_col4 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_4a42d512_8df2_11ea_92bb_000acd2bfab2row9_col5 {
#             background-color:  #b8c6e0;
#             color:  #000000;

# %% [markdown]
# # coll

# %%
coll.sort_values(by='ratio', ascending=False)[:10].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row0_col5 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row1_col5 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T
{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row9_col0 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row9_col1 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row9_col2 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row9_col3 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4a48a068_8df2_11ea_8b94_000acd2bfab2row9_col5 {
#             background-color:  #f7f0f7;
#             color:  #000000;

# %%
coll.sort_values(by='nb', ascending=False)[['nb', 'mass_dist','combo']][:10].fillna(0).style.background_gradient()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-aa669ae92ffc> in <module>
# ----> 1 coll.sort_values(by='nb', ascending=False)[['nb', 'mass_dist','combo']][:10].fillna(0).style.background_gradient()
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# D:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# D:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# D:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['mass_dist', 'combo'] not in index"

# %% [markdown]
# # jaccard similarity

# %% [markdown]
# # for collb

# %%
jaccard_scoresb = nb.frame({'ratio': {x:df_jaccard(collb, 'nb', 'ratio', x) for x in range(5, 210, 5)},
                            'srel': {x:df_jaccard(collb, 'nb', 'srel', x) for x in range(5, 210, 5)},
                           'lrel': {x:df_jaccard(collb, 'nb', 'lrel', x) for x in range(5, 210, 5)}
                          }).transpose()

# %%
jaccard_scoresb.plot(title='Jaccard similarity of reference corpus');

# %% [markdown]
# # for coll

# %%
jaccard_scores = nb.frame({'ratio': {x:df_jaccard(coll, 'nb', 'ratio', x) for x in range(5, 210, 5)},
                            'srel': {x:df_jaccard(coll, 'nb', 'srel', x) for x in range(5, 210, 5)},
                           'lrel': {x:df_jaccard(coll, 'nb', 'lrel', x) for x in range(5, 210, 5)}
                          }).transpose()

# %%
jaccard_scores.plot();
