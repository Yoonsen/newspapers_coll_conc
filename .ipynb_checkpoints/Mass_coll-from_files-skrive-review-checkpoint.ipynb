# %% [markdown]
# # Data and computations for paper
#
# Lars G. Johnsen
# National Library of Norway

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
mu.update('collocations')
from collocations import dist_coll_urn, urn_coll, calculate_midpoint, dist
import pandas as pd
# Out:
# Updated file `D:\documents\GitHub\newspapers_coll_conc\collocations.py`

# %%
movealpha = lambda x: list(tuple([x[-1]]) + tuple(x[:-1]))

# %%
def df_jaccard(df, col1, col2, number=100, asc=False):
    s1 = df.sort_values(by=col1, ascending=asc)[:number].index
    s2 = df.sort_values(by=col2, ascending=asc)[:number].index
    
    #print(len(set(s1)&set(s2)))
    
    return jaccard(s1, s2)

# %%
def jaccards(s1, s2):
    return len(set(s1)&set(s2)),len(set(s1)|set(s2))

# %%
def jaccard(s1, s2):
    return len(set(s1)&set(s2))/len(set(s1)|set(s2))

# %%
def large_corpus_dist_coll(collword, urns = None, after= 10, before = 0, n = 300):
    colls_freq = []
    colls_dist = []
    coll = pd.DataFrame()
    for i in range(0, len(urns), n):
        a = urn_coll(collword, urns = urns[i:i + n], after= after, before = before)
        colls_freq.append(nb.frame(a['freq']))
        colls_dist.append(nb.frame(a['dist']))
    coll['freq'] = pd.concat(colls_freq, axis=1, sort=False).sum(axis=1)
    coll['dist'] = pd.concat(colls_dist, axis = 1, sort=False).mean(axis=1)
    coll['dist_score'] = round(dist(coll['dist'], calculate_midpoint(before, after), coll['freq']), 2)
    return coll

# %%
def large_corpus_coll(collword, urns = None, after= 5, before = 5, n = 300):
    colls = []
    for i in range(0, len(urns), n):
        colls.append(nb.urn_coll(collword, urns=urns[i:i + n], after= after, before = before))
    coll = pd.concat(colls, axis=1, sort=False).sum(axis=1)
    return pd.DataFrame(coll)

# %%
def make_coll_df(small, large, tot):
    """take two collocations, small and large, and a reference tot. The reference must av a column call tot as well"""
    coll = pd.DataFrame()
    small = small[~small.reindex().duplicated()]
    large = large[~large.reindex().duplicated()]
    coll['small'] = small['freq'].astype(int)
    coll['large'] = large['freq'].astype(int)
    #coll['ratio'] = coll['small']/coll['large']
    coll['srel'] = coll.small/coll.small.sum()
    coll['lrel'] = coll.large/coll.large.sum()
    coll['ratio'] = coll.srel/coll.lrel
    coll['adjusted'] = coll.small**0.01*coll.ratio
    coll['ref-small'] = coll.srel/tot.tot
    coll['ref-large'] = coll.lrel/tot.tot
    coll = coll.fillna(0)
    return coll.astype({'small':'int32', 'large':'int32'})

# %% [markdown]
# ### Reference corpus
#
# The reference is the total counts from approximately 450 000 books from nb.no

# %%
tot = nb.frame(nb.totals(50000), 'tot')

# %%
nb.normalize_corpus_dataframe(tot)
tot.head()
# Out:
#           tot
# .    0.058921
# ,    0.051453
# og   0.025297
# i    0.021425
# det  0.012728

# %% [markdown]
# # Corpus
#
# The corpus for doing collocations is a sample of 800 books from fictional literature, dewey decimal code 813.

# %%
smd = 5
lmd = 10
collword = 'skrive'

# %%
def filenames(smd = smd, lmd = lmd, collword = collword, corpus_size= 1000, period = (1980, 2000)):
    return {
    'small_right': '_'.join([collword, str(smd), str(corpus_size), '-'.join([str(x) for x in period]), str(0), str(int(2*smd)), '.csv']),
    'large_right': '_'.join([collword, str(smd), str(corpus_size),  '-'.join([str(x) for x in period]), str(0), str(int(2*lmd)), '.csv']),
    'small_left' : '_'.join([collword, str(lmd), str(corpus_size),  '-'.join([str(x) for x in period]), str(int(2*smd)), str(0), '.csv']),
    'large_left' : '_'.join([collword, str(lmd), str(corpus_size),  '-'.join([str(x) for x in period]), str(int(2*lmd)), str(0), '.csv'])
        }

# %%
names = filenames(smd=smd, lmd=lmd, collword=collword)
names
# Out:
# {'small_right': 'skrive_5_1000_1980-2000_0_10_.csv',
#  'large_right': 'skrive_5_1000_1980-2000_0_20_.csv',
#  'small_left': 'skrive_10_1000_1980-2000_10_0_.csv',
#  'large_left': 'skrive_10_1000_1980-2000_20_0_.csv'}

# %%
a1 = pd.read_csv(names['small_right'], index_col=0)
a2 = pd.read_csv(names['large_right'], index_col=0)
b1 = pd.read_csv(names['small_left'], index_col=0)
b2 = pd.read_csv(names['large_left'], index_col=0)

# %% [markdown]
# Set up the distance parameters and collword, smd is small distance while lmd is large distance. These values are half of the actual window, and used to make a normalized score, call ascore. See below.

# %% [markdown]
# ## Create collocation dataframe
#
# Based on data from a1 and a2, and b1 and b2. The name for the collocations after is `coll` while `collb` is for the collocates coming before.

# %%
coll = make_coll_df(a1, a2, tot)
collb = make_coll_df(b1, b2, tot)

# %% [markdown]
# ## Sorting
#
# Sorting on the reference is by column 'nb'

# %%
coll[coll.small < coll.large].sort_values(by='ratio', ascending=False)[:20][:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row0_col0 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row0_col1 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row0_col2 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row0_col3 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row0_col6 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row0_col7 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row1_col0 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row1_col1 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row1_col2 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row7_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row7_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row7_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_2ce0f19a_8cb3_11ea_97c9_000acd2bfab2row7_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;

# %%
coll = coll.drop('ker')

# %%
coll[coll.small < coll.large].sort_values(by='adjusted', ascending=False)[:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row0_col0 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row0_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row0_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row0_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row0_col6 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row0_col7 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row1_col0 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row1_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row1_col2 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row1_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row1_col4 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row1_col5 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row1_col6 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row1_col7 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row2_col0 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row2_col1 {
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row5_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row5_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row5_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row5_col4 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row5_col5 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row5_col6 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row5_col7 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row6_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row6_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row6_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row6_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row6_col4 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row6_col5 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row6_col6 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row6_col7 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row7_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row7_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row7_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_2cecafa8_8cb3_11ea_a461_000acd2bfab2row7_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;

# %%
coll[coll.small < coll.large].sort_values(by='ratio', ascending=False)[:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row0_col0 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row0_col1 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row0_col2 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row0_col3 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T
{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row6_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row6_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row6_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row6_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row6_col4 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row6_col5 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row6_col6 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row6_col7 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row7_col0 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row7_col1 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row7_col2 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_2cf73576_8cb3_11ea_8c7f_000acd2bfab2row7_col3 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;

# %%
common = coll.loc[[',','.', 'og','eller', 'i', 'på']]

# %%
common['translate'] = [',', '.', 'and', 'or', 'in', 'on']

# %%
common = common[list(tuple([common.columns[-1]]) + tuple(common.columns[:-1]))]

# %%
common[['translate', 'srel', 'ratio', 'ref-small']]
# Out:
#       translate      srel     ratio  ref-small
# ,             ,  0.050074  0.987992   0.973187
# .             .  0.071018  0.999720   1.205309
# og          and  0.031587  0.957841   1.248611
# eller        or  0.006465  1.123533   2.354717
# i            in  0.023345  0.921231   1.089614
# på           on  0.020415  1.060405   2.128986

# %% [markdown]
# # collb

# %%
collb[collb.small < collb.large].sort_values(by='adjusted', ascending=False)[:40].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_2d0f001c_8cb3_11ea_86ae_000acd2bfab2row0_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_2d0f001c_8cb3_11ea_86ae_000acd2bfab2row0_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_2d0f001c_8cb3_11ea_86ae_000acd2bfab2row0_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_2d0f001c_8cb3_11ea_86ae_000acd2bfab2row0_col3 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_2d0f001c_8cb3_11ea_86ae_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2d0f001c_8cb3_11ea_86ae_000acd2bfab2row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T
{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2d0f001c_8cb3_11ea_86ae_000acd2bfab2row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;

# %%
collb.sort_values(by='ref-large', ascending=False)[:40].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row0_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row0_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row0_col2 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row0_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row0_col4 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row0_col5 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row1_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row1_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row1_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row1_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row1_col4 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row1_col5 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row1_col6 {
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row1_col7 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row2_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row2_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row2_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row2_col3 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row2_col4 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row2_col5 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row2_col6 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row2_col7 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row3_col4 {
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row3_col5 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row3_col6 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row3_col7 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row4_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row4_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row4_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row4_col3 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row4_col4 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row4_col5 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row4_col6 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row4_col7 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row5_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row5_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row5_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row5_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row5_col4 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row5_col5 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row5_col6 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row5_col7 {
#             background-color:  #88b1d4;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row6_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row6_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row6_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row6_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row6_col4 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row6_col5 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row6_col6 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row6_col7 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row7_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row7_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row7_col2 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_6ff766c6_8cb3_11ea_b614_000acd2bfab2row7_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;

# %% [markdown]
# # coll

# %%
coll[coll.small < coll.large].sort_values(by='ratio', ascending=False)[:30].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_740619f8_8cb3_11ea_b426_000acd2bfab2row0_col0 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_740619f8_8cb3_11ea_b426_000acd2bfab2row0_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_740619f8_8cb3_11ea_b426_000acd2bfab2row0_col2 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_740619f8_8cb3_11ea_b426_000acd2bfab2row0_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_740619f8_8cb3_11ea_b426_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_740619f8_8cb3_11ea_b426_000acd2bfab2row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_740619f8_8cb3_11ea_b426_000acd2bfab2row0_col6 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_740619f8_8cb3_11ea_b426_000acd2bfab2row0_col7 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_740619f8_8cb3_11ea_b426_000acd2bfab2row1_col0 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_740619f8_8cb3_11ea_b426_000acd2bfab2row1_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_740619f8_8cb3_11ea_b426_000acd2bfab2row1_col2 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_740619f8_8cb3_11ea_b426_000acd2bfab2row7_col2 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_740619f8_8cb3_11ea_b426_000acd2bfab2row7_col3 {
#             background-color:  #e6e2ef;
#             color:  #000000;

# %%
coll.sort_values(by='ref-small', ascending=False)[:30].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row0_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row0_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row0_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row0_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row0_col7 {
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row1_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row1_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row1_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row1_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row1_col4 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row1_col5 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row1_col6 {
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row1_col7 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row2_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row2_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row2_col2 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row2_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row2_col4 {
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row5_col3 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row5_col4 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row5_col5 {
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row5_col6 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row5_col7 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row6_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row6_col1 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row6_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row6_col3 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row6_col4 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row6_col5 {
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row6_col6 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row6_col7 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row7_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row7_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row7_col2 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_74a9e3cc_8cb3_11ea_849c_000acd2bfab2row7_col3 {
#             background-color:  #f4eef6;
#             color:  #000000;

# %% [markdown]
# # top 10 for translation

# %%
top10ratio = coll[coll.small < coll.large].sort_values(by='ratio', ascending=False)[:10]
top10ref = coll[coll.small < coll.large].sort_values(by='ref-large', ascending=False)[:10]

# %%
top10ratio.index
# Out:
# Index(['lapp', 'testamente', 'erklæring', 'tale', 'sammendrag', 'dagbok',
#        'skuespill', 'artikkel', 'redigere', 'innlegg'],
#       dtype='object')

# %%
top10ratio['trans'] = ['note', 'wills', 'statement', 'speech', 'summary', 'diary',
       'play', 'article', 'edit', 'post']

# %%
top10ratio = top10ratio[movealpha(top10ratio.columns)]

# %%
top10ratio[['trans', 'srel', 'ratio', 'ref-large']]
# Out:
#                 trans      srel     ratio  ref-large
# lapp             note  0.000340  1.817571  35.645309
# testamente      wills  0.000246  1.781508  16.736618
# erklæring   statement  0.000208  1.758669  14.967379
# tale           speech  0.000208  1.758669   1.057462
# sammendrag    summary  0.000208  1.758669  36.975245
# dagbok          diary  0.000605  1.754101  61.808199
# skuespill        play  0.000189  1.744134  13.914268
# artikkel      article  0.001059  1.732882  17.847388
# redigere         edit  0.000170  1.726693  43.804968
# innlegg          post  0.000151  1.705376  10.438171

# %%
top10ref.index
# Out:
# Index(['stiler', 'tastaturet', 'memoarer', 'skrivemaskin', 'diktat', 'dagbok',
#        'låter', 'reserverte', 'markøren', 'arket'],
#       dtype='object')

# %%
top10ref['trans'] = ['writings',  'keyboard', 'memoirs', 'typewriter', 'dictation', 'diary',
       'songs', 'reserved', 'cursor', 'sheet']

# %%
top10ref = top10ref[movealpha(top10ref.columns)]

# %%
top10ref[['trans', 'srel', 'ratio', 'ref-large']]
# Out:
#                    trans      srel     ratio  ref-large
# stiler          writings  0.000189  1.370391  91.100489
# tastaturet      keyboard  0.000189  1.009762  89.045788
# memoarer         memoirs  0.000151  1.395307  87.995204
# skrivemaskin  typewriter  0.000132  1.033064  85.457715
# diktat         dictation  0.000132  1.492204  84.394674
# dagbok             diary  0.000605  1.754101  61.808199
# låter              songs  0.000265  1.678729  59.994321
# reserverte      reserved  0.000076  1.096313  55.134238
# markøren          cursor  0.000132  0.839365  48.129495
# arket              sheet  0.000284  0.992352  45.875567

# %% [markdown]
# # jaccard similarity
#
# compare over a range

# %%
rng = range(2,40,2)

# %% [markdown]
# # for collb

# %%
jaccard_scoresb = nb.frame({'ratio': {x:df_jaccard(collb[collb.small < collb.large], 'ref-small', 'ratio', x) for x in rng},
                            'srel': {x:df_jaccard(collb[collb.small < collb.large], 'ref-large', 'ratio', x) for x in rng},
                           'lrel': {x:df_jaccard(collb[collb.small < collb.large], 'ref-small', 'adjusted', x) for x in rng}
                          }).transpose()

# %%
ax = jaccard_scoresb['ratio'].plot(title='compared to reference corpus');
ax.set_xlabel("Number of words")
ax.set_ylabel("Jaccard score")
# Out:
# Text(0, 0.5, 'Jaccard score')

# %% [markdown]
# # for coll

# %%
jaccard_scores = nb.frame({'ratio': {x:df_jaccard(coll[coll.small < coll.large], 'ref-small', 'ratio', x) for x in rng},
                            'adjusted': {x:df_jaccard(coll[coll.small < coll.large], 'ref-small', 'adjusted', x) for x in rng},
                           'ref-large': {x:df_jaccard(coll[coll.small < coll.large], 'ref-large', 'ratio', x) for x in rng}
                          }).transpose()

# %%
ax = jaccard_scores['ratio'].plot(title='compared to reference corpus');
ax.set_xlabel("Number of words")
ax.set_ylabel("Jaccard score")
# Out:
# Text(0, 0.5, 'Jaccard score')

# %%
ax = jaccard_scores.plot(title='compared to reference corpus');
ax.set_xlabel("Number of words")
ax.set_ylabel("Jaccard score")
# Out:
# Text(0, 0.5, 'Jaccard score')

# %%
jaccards(collb[collb.small < collb.large].sort_values(by='ratio', ascending = False)[:60].index, collb.sort_values(by='nb', ascending=False)[:100].index)
