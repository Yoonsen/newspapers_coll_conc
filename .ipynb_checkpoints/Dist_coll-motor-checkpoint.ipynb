# %% [markdown]
# # Data and computations for paper
#
# Lars G. Johnsen
# National Library of Norway

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
mu.update('collocations')
from collocations import dist_coll_urn, urn_coll, calculate_midpoint, dist
import pandas as pd
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\newspapers_coll_conc\collocations.py`

# %%
def df_jaccard(df, col1, col2, number=100, asc=False):
    s1 = df.sort_values(by=col1, ascending=asc)[:number].index
    s2 = df.sort_values(by=col2, ascending=asc)[:number].index
    
    #print(len(set(s1)&set(s2)))
    
    return jaccard(s1, s2)

# %%
def jaccards(s1, s2):
    return len(set(s1)&set(s2)),len(set(s1)|set(s2))

# %%
def jaccard(s1, s2):
    return len(set(s1)&set(s2))/len(set(s1)|set(s2))

# %%
def large_corpus_dist_coll(collword, urns = None, after= 10, before = 0, n = 300):
    colls_freq = []
    colls_dist = []
    coll = pd.DataFrame()
    for i in range(0, len(urns), n):
        a = urn_coll(collword, urns = urns[i:i + n], after= after, before = before)
        colls_freq.append(nb.frame(a['freq']))
        colls_dist.append(nb.frame(a['dist']))
    coll['freq'] = pd.concat(colls_freq, axis=1, sort=False).sum(axis=1)
    coll['dist'] = pd.concat(colls_dist, axis = 1, sort=False).mean(axis=1)
    coll['dist_score'] = round(dist(coll['dist'], calculate_midpoint(before, after), coll['freq']), 2)
    return coll

# %%
def large_corpus_coll(collword, urns = None, after= 5, before = 5, n = 300):
    colls = []
    for i in range(0, len(urns), n):
        colls.append(nb.urn_coll(collword, urns=urns[i:i + n], after= after, before = before))
    coll = pd.concat(colls, axis=1, sort=False).sum(axis=1)
    return pd.DataFrame(coll)

# %%
def make_coll_df(small, large, tot):
    """take two collocations, small and large, and a reference tot. The reference must av a column call tot as well"""
    coll = pd.DataFrame()
    coll['small'] = small['freq']
    coll['large'] = large['freq']
    #coll['ratio'] = coll['small']/coll['large']
    coll['srel'] = coll.small/coll.small.sum()
    coll['lrel'] = coll.large/coll.large.sum()
    coll['ratio'] = coll.srel/coll.lrel
    coll['adjusted'] = coll.small**0.01*coll.ratio
    coll['nb'] = coll.small/tot.tot
    return coll

# %%
import pandas as pd

# %%
def make_dcoll_df(dists, norm, tot):
    
    return nb.frame(
        {
        'score':(dists.freq/dists.freq.sum())**0.01*abs(norm/dists['2']), 
        'dist':dists['1'],
        'nb':(dists.freq/dists.freq.sum())/tot.tot
        }
    ).transpose()

# %% [markdown]
# ### Reference corpus
#
# The reference is the total counts from approximately 450 000 books from nb.no

# %%
tot = nb.frame(nb.totals(50000), 'tot')

# %%
nb.normalize_corpus_dataframe(tot)
tot.head()
# Out:
#           tot
# .    0.058921
# ,    0.051453
# og   0.025297
# i    0.021425
# det  0.012728

# %% [markdown]
# # Corpus
#
# The corpus for doing collocations is a sample of 800 books from fictional literature, dewey decimal code 813.

# %%
smd = 5
lmd = 10
collword = 'spise'

# %% [markdown]
# # Store the data subsequent use

# %%
a1 = pd.read_csv('spise_large_after.csv', index_col=0)
a2 = pd.read_csv('spise_small_after.csv', index_col=0)
b1 = pd.read_csv('spise_large_before.csv', index_col=0)
b2 = pd.read_csv('spise_small_before.csv', index_col=0)

# %% [markdown]
# ## Create collocation dataframe
#
# Based on data from a1 and a2, and b1 and b2. The name for the collocations after is `coll` while `collb` is for the collocates coming before.

# %%
coll = make_dcoll_df(a1, lmd, tot)

# %%
collb = make_dcoll_df(b1, lmd, tot)

# %% [markdown]
# ## Sorting
#
# Sorting on the reference is by column 'nb'

# %%
coll.sort_values(by='score', ascending=False)[:20][:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow0_col0 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow0_col1 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow1_col0 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow1_col2 {
#             background-color:  #03446a;
#             color:  #f1f1f1;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow2_col0 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow2_col1 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow2_col2 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow3_col0 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow3_col1 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow3_col2 {
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow4_col0 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow4_col2 {
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow5_col2 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow6_col0 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow6_col2 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow7_col0 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T
{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow17_col2 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow18_col0 {
#             background-color:  #157ab5;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow18_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow18_col2 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow19_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow19_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1449b88a_5007_11ea_8c3e_7c7635c6d85arow19_col2 {
#             background-color:  #fff7fb;

# %%
coll.sort_values(by='nb', ascending=False)[:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_22060218_5007_11ea_8087_7c7635c6d85arow0_col0 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow0_col2 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow1_col0 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow1_col1 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow1_col2 {
#             background-color:  #034369;
#             color:  #f1f1f1;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow2_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow2_col1 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow2_col2 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow3_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow3_col1 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow3_col2 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow4_col0 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow4_col1 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow4_col2 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow5_col0 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow5_col1 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow5_col2 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow15_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow15_col2 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow16_col0 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow16_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow16_col2 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow17_col0 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow17_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow17_col2 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow18_col0 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow18_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow18_col2 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow19_col0 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow19_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_22060218_5007_11ea_8087_7c7635c6d85arow19_col2 {
#             background-color:  #ece7f2;

# %%
coll.loc[[',','.', 'og','eller', 'i', 'på']]
# Out:
#            dist        nb     score
# ,      4.863514  0.931466  1.996041
# .      4.935973  1.299001  1.972931
# og     5.270779  1.125352  1.831188
# eller  3.964142  1.254131  2.386022
# i      5.380861  0.741956  1.783326
# på     5.568382  1.614828  1.722042

# %% [markdown]
# # collb

# %%
collb.sort_values(by='nb', ascending=False)[:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_34932900_5007_11ea_a04d_7c7635c6d85arow0_col0 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow0_col2 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow1_col0 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow1_col1 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow1_col2 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow2_col0 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow2_col1 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow2_col2 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow11_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow12_col0 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow12_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow12_col2 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow13_col0 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow13_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow13_col2 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow14_col0 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow14_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow14_col2 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow15_col0 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow15_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow15_col2 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow16_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow16_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow16_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow17_col0 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow17_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow17_col2 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow18_col0 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow18_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow18_col2 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow19_col0 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow19_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34932900_5007_11ea_a04d_7c7635c6d85arow19_col2 {
#             background-color:  #dad9ea;

# %%
collb.sort_values(by='score', ascending=False)[:40].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow0_col0 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow0_col1 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow1_col2 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow2_col0 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow2_col1 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow2_col2 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow3_col2 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow4_col0 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow4_col2 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow5_col0 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow5_col1 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow5_col2 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow6_col0 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow6_col2 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow7_col0 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow7_col1 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow7_col2 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow8_col0 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow8_col1 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow8_col2 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow9_col0 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow9_col1 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow9_col2 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow10_col0 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow10_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow10_col2 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow11_col0 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow11_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow11_col2 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow12_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow12_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow12_col2 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow13_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow13_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow13_col2 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow14_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow14_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow14_col2 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow15_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow15_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow15_col2 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow16_col0 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow16_col1 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow16_col2 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow17_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow17_col1 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow17_col2 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow18_col0 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow18_col1 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow18_col2 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow19_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow19_col1 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_3694627a_5007_11ea_8a6d_7c7635c6d85arow19_col2 {
#             background-color:  #e5e1ef;

# %%
collb.sort_values(by='nb', ascending=False).loc[['sterk', 'kruttsterk']].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85arow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85arow0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85arow0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85arow1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85arow1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85arow1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dist</th>        <th class="col_heading level0 col1" >nb</th>        <th class="col_heading level0 col2" >score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85alevel0_row0" class="row_heading level0 row0" >sterk</th>
#                         <td id="T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85arow0_col0" class="data row0 col0" >-6.45833</td>
#                         <td id="T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85arow0_col1" class="data row0 col1" >0.503708</td>
#                         <td id="T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85arow0_col2" class="data row0 col2" >1.40856</td>
#             </tr>
#             <tr>
#                         <th id="T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85alevel0_row1" class="row_heading level0 row1" >kruttsterk</th>
#                         <td id="T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85arow1_col0" class="data row1 col0" >-7</td>
#                         <td id="T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85arow1_col1" class="data row1 col1" >0</td>
#                         <td id="T_3c2ac54c_5007_11ea_bd7a_7c7635c6d85arow1_col2" class="data row1 col2" >1.5922</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # coll

# %% [markdown]
# # jaccard similarity
#
# compare over a range

# %%
rng = range(2,40,2)

# %% [markdown]
# # for collb

# %%
jaccard_scoresb = nb.frame({'ratio': {x:df_jaccard(collb, 'nb', 'score', x) for x in rng}
                            }).transpose()

# %%
ax = jaccard_scoresb['ratio'].plot(title='compared to reference corpus');
ax.set_xlabel("Number of words")
ax.set_ylabel("Jaccard score")
# Out:
# Text(0, 0.5, 'Jaccard score')

# %% [markdown]
# # for coll

# %%
jaccard_scores = nb.frame({'ratio': {x:df_jaccard(coll, 'nb', 'score', x) for x in rng}     }).transpose()

# %%
ax = jaccard_scores['ratio'].plot(title='compared to reference corpus');
ax.set_xlabel("Number of words")
ax.set_ylabel("Jaccard score")
# Out:
# Text(0, 0.5, 'Jaccard score')

# %%
jaccards(collb[collb.small < collb.large].sort_values(by='ratio', ascending = False)[:60].index, collb.sort_values(by='nb', ascending=False)[:100].index)
# Out:
# (8, 152)
