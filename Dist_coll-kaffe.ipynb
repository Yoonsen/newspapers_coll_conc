# %% [markdown]
# # Data and computations for paper
#
# Lars G. Johnsen
# National Library of Norway

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
mu.update('collocations')
from collocations import dist_coll_urn, urn_coll, calculate_midpoint, dist
import pandas as pd
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\newspapers_coll_conc\collocations.py`

# %%
def df_jaccard(df, col1, col2, number=100, asc=False):
    s1 = df.sort_values(by=col1, ascending=asc)[:number].index
    s2 = df.sort_values(by=col2, ascending=asc)[:number].index
    
    #print(len(set(s1)&set(s2)))
    
    return jaccard(s1, s2)

# %%
movealpha = lambda x: list(tuple([x[-1]]) + tuple(x[:-1]))

# %%
def jaccards(s1, s2):
    return len(set(s1)&set(s2)),len(set(s1)|set(s2))

# %%
def jaccard(s1, s2):
    return len(set(s1)&set(s2))/len(set(s1)|set(s2))

# %%
import pandas as pd

# %%
def make_dcoll_df(dists, norm, tot, exp=0):
    
    coll =  nb.frame(
        {
        'freq':dists['freq'].astype(int),
        'score':(dists.freq/dists.freq.sum())**exp*abs(norm/dists['2']), 
        'dist':dists['1'],
            'dist_' : dists['2'],
        'reference':(dists.freq/dists.freq.sum())/tot.tot
        }
    ).transpose()
    coll = coll.fillna(0)
    return coll.astype({'freq':'int32'})

# %% [markdown]
# ### Reference corpus
#
# The reference is the total counts from approximately 450 000 books from nb.no

# %%
tot = nb.frame(nb.totals(50000), 'tot')

# %%
nb.normalize_corpus_dataframe(tot)
tot.head()
# Out:
#           tot
# .    0.058921
# ,    0.051453
# og   0.025297
# i    0.021425
# det  0.012728

# %% [markdown]
# # Corpus
#
# The corpus for doing collocations is a sample of 800 books from fictional literature, dewey decimal code 813.

# %%
smd = 5
lmd = 10
collword = 'kaffe'

# %%
def filenames(smd = smd, lmd = lmd, collword = collword, corpus_size= 1000, period = (1980, 2000)):
    return {
    'small_right': '_'.join([collword, str(smd), str(corpus_size), '-'.join([str(x) for x in period]), str(0), str(int(2*smd)), '.csv']),
    'large_right': '_'.join([collword, str(smd), str(corpus_size),  '-'.join([str(x) for x in period]), str(0), str(int(2*lmd)), '.csv']),
    'small_left' : '_'.join([collword, str(lmd), str(corpus_size),  '-'.join([str(x) for x in period]), str(int(2*smd)), str(0), '.csv']),
    'large_left' : '_'.join([collword, str(lmd), str(corpus_size),  '-'.join([str(x) for x in period]), str(int(2*lmd)), str(0), '.csv'])
        }

# %% [markdown]
# # Store the data subsequent use

# %%
names = filenames()
names
# Out:
# {'small_right': 'kaffe_5_1000_1980-2000_0_10_.csv',
#  'large_right': 'kaffe_5_1000_1980-2000_0_20_.csv',
#  'small_left': 'kaffe_10_1000_1980-2000_10_0_.csv',
#  'large_left': 'kaffe_10_1000_1980-2000_20_0_.csv'}

# %%
a1 = pd.read_csv(names['small_right'], index_col=0)
a2 = pd.read_csv(names['large_right'], index_col=0)
b1 = pd.read_csv(names['small_left'], index_col=0)
b2 = pd.read_csv(names['large_left'], index_col=0)

# %% [markdown]
# ## Create collocation dataframe
#
# Based on data from a1 and a2, and b1 and b2. The name for the collocations after is `coll` while `collb` is for the collocates coming before.

# %%
coll = make_dcoll_df(a1, lmd, tot)

# %%
collb = make_dcoll_df(b1, lmd, tot)

# %% [markdown]
# ## Sorting
#
# Sorting on the reference is by column 'nb'

# %%
coll[coll.freq > 10].sort_values(by='score', ascending=False)[:20][:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow0_col2 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow0_col4 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow1_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow1_col1 {
#             background-color:  #045585;
#             color:  #f1f1f1;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow1_col3 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow1_col4 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow2_col0 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow2_col1 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow2_col2 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow2_col3 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow2_col4 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow3_col1 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow3_col2 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow3_col3 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow4_col0 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow4_col1 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow4_col2 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow4_col3 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow5_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow5_col1 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow5_col2 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow5_col3 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow5_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow6_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow6_col1 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow6_col2 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow6_col3 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow6_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow7_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow7_col1 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow7_col2 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow7_col3 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow7_col4 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow8_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow8_col1 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow8_col2 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow8_col3 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow8_col4 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow9_col0 {
#             background-color:  #045280;
#             color:  #f1f1f1;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow9_col1 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow9_col2 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow9_col3 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow10_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow10_col1 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow10_col2 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow10_col3 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow10_col4 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow11_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow11_col1 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow11_col2 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow11_col3 {
#             background-color:  #589ec8;
#             color:  #000000;
#         }    #T_e7210638_51ed_11ea_b19f_7c7635c6d85arow11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
coll.sort_values(by='reference', ascending=False)[:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow0_col0 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow0_col1 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow0_col2 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow0_col3 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow1_col0 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow1_col4 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow2_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow2_col1 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow2_col2 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow2_col3 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow2_col4 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow3_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow3_col1 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow3_col2 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow3_col3 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow3_col4 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow4_col0 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow4_col1 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow4_col2 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow4_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow4_col4 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow5_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow5_col1 {
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow5_col2 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow5_col3 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow5_col4 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow6_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow6_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow6_col4 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow7_col0 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow7_col1 {
#             background-color:  #88b1d4;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow7_col2 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow7_col3 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow7_col4 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow8_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow8_col1 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow8_col2 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow8_col3 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow8_col4 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow9_col1 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow9_col2 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow9_col3 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow9_col4 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow10_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow10_col1 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow10_col2 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow10_col3 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow10_col4 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow11_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow11_col1 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow11_col2 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow11_col3 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_8caa5e02_51ed_11ea_a28c_7c7635c6d85arow11_col4 {
#             background-color:  #dbdaeb;
#             color:  #0

# %%
coll.loc[[',','.', 'og','eller', 'i', 'på','ned']]
# Out:
#        freq     score      dist  dist_  reference
# ,      3215  2.227171  4.493606   4.49   1.153050
# .      3964  2.053388  4.865904   4.87   1.241492
# og     2753  2.551020  3.919626   3.92   2.008213
# eller   215  3.012048  3.313258   3.32   1.445120
# i       980  1.886792  5.304478   5.30   0.844082
# på      847  1.788909  5.585198   5.59   1.629991
# ned      58  1.631321  6.143995   6.13   1.674834

# %% [markdown]
# # collb

# %%
collb.sort_values(by='reference', ascending=False)[:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow0_col1 {
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow0_col2 {
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow1_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow1_col1 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow1_col2 {
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow1_col3 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow1_col4 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow2_col0 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow2_col1 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow2_col2 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow2_col3 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow2_col4 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow3_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow3_col1 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow3_col2 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow3_col3 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow3_col4 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow4_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow4_col1 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow4_col2 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow4_col3 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow4_col4 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow5_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow5_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow5_col4 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow6_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow6_col1 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow6_col2 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow6_col3 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow6_col4 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow7_col0 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow7_col1 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow7_col2 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow7_col3 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow7_col4 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow8_col0 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow8_col1 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow8_col2 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow8_col3 {
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow8_col4 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow9_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow9_col1 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow9_col2 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow9_col3 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow9_col4 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow10_col0 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow10_col1 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow10_col2 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow10_col3 {
#             background-color:  #045280;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow10_col4 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow11_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow11_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow11_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow11_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b7b3f6a8_51ed_11ea_97aa_7c7635c6d85arow11_col4 {
#             background-color:  #f5eff6;
#             color:  #0

# %%
collb = collb.drop('kop')

# %%
collb[collb.freq > 20].sort_values(by='score', ascending=False)[:40].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow1_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow1_col1 {
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow1_col2 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow1_col3 {
#             background-color:  #03446a;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow1_col4 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow2_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow2_col1 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow2_col2 {
#             background-color:  #03446a;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow2_col3 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow2_col4 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow3_col0 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow3_col1 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow3_col2 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow3_col3 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow3_col4 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow4_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow4_col1 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow4_col2 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow4_col3 {
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow4_col4 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow5_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow5_col1 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow5_col2 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow5_col3 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow5_col4 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow6_col1 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow6_col2 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow6_col3 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow6_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow7_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow7_col1 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow7_col2 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow7_col3 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow7_col4 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow8_col0 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow8_col1 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow8_col2 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow8_col3 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow8_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow9_col0 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow9_col1 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow9_col2 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow9_col3 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow9_col4 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow10_col0 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow10_col1 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow10_col2 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow10_col3 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow10_col4 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow11_col0 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow11_col1 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow11_col2 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow11_col3 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_c00d7c18_51f0_11ea_ad48_7c7635c6d85arow11_col4 {
#             background-color:  #efe9f3;
#             color:  #0

# %%
collb.loc[[x for x in ['kakao', 'kaffe', 'te', 'sjokolade', 'latte', 'buljong'] if x in collb.index]]
# Out:
#            freq     score      dist  dist_   reference
# kakao        35  2.673797 -3.686420  -3.74  245.101930
# kaffe       157  1.497006 -6.683458  -6.68   87.791997
# te          120  3.086420 -3.224290  -3.24   16.054192
# sjokolade    19  2.267574 -4.351852  -4.41   54.396609
# buljong       1  1.818182 -6.000000  -5.50    9.346958

# %%
common = coll.loc[[',','.', 'og','eller', 'i', 'på']]

# %%
common['translate'] = [',', '.', 'and', 'or', 'in', 'on']

common = common[movealpha(common.columns)]

# %%
common
# Out:
#       translate  freq     score      dist  dist_  reference
# ,             ,  3215  2.227171  4.493606   4.49   1.153050
# .             .  3964  2.053388  4.865904   4.87   1.241492
# og          and  2753  2.551020  3.919626   3.92   2.008213
# eller        or   215  3.012048  3.313258   3.32   1.445120
# i            in   980  1.886792  5.304478   5.30   0.844082
# på           on   847  1.788909  5.585198   5.59   1.629991

# %%
top10ratio = collb.sort_values(by='score', ascending=False)[:10]

# %%
top10ratio.index
# Out:
# Index(['nytraktet', 'nytrukket', 'kopp', 'Svart', 'nykokt', 'slurk', 'pund',
#        'svart', 'Mer', 'nylaget'],
#       dtype='object')

# %%
top10ratio['translate'] = ['freshly drawn', 'freshly drawn', 'cup', 'black', 'freshly boiled', 'sip', 'pound',
       'black', 'more', 'freshly made']

# %%
top10ratio  = top10ratio[movealpha(top10ratio.columns)]

# %%
top10ratio
# Out:
#                 translate  freq     score      dist  dist_    reference
# nytraktet   freshly drawn    15  7.692308 -1.000000  -1.30     0.000000
# nytrukket   freshly drawn    14  7.575758 -1.000000  -1.32     0.000000
# kopp                  cup   850  7.518797 -1.325735  -1.33  1119.407652
# Svart               black    12  7.246377 -1.000000  -1.38    59.552151
# nykokt     freshly boiled    12  7.246377 -1.000000  -1.38     0.000000
# slurk                 sip    49  6.993007 -1.342857  -1.43   118.641838
# pund                pound    13  6.944444 -1.100000  -1.44    17.839419
# svart               black   107  6.802721 -1.428837  -1.47    32.018644
# Mer                  more     9  6.666667 -1.000000  -1.50     6.771161
# nylaget      freshly made     9  6.666667 -1.000000  -1.50     0.000000

# %%
top10ref = collb.sort_values(by='reference', ascending=False)[:10]

# %%
top10ref.index
# Out:
# Index(['kopp', 'kanne', 'skjenket', 'mineralvann', 'rykende', 'Viktigste',
#        'kakao', 'serverte', 'kopper', 'vafler'],
#       dtype='object')

# %%
top10ref['translate'] = ['cup', 'jug', 'poured', 'mineral water', 'smoking', 'main',
       'cocoa', 'served', 'cups', 'waffles']

# %%
top10ref  = top10ref[movealpha(top10ref.columns)]

# %%
top10ref
# Out:
#                  translate  freq     score      dist  dist_    reference
# kopp                   cup   850  7.518797 -1.325735  -1.33  1119.407652
# kanne                  jug    58  5.617978 -1.709788  -1.78   581.516609
# skjenket            poured   163  3.649635 -2.718562  -2.74   351.468955
# mineralvann  mineral water    25  3.401361 -2.833333  -2.94   327.723096
# rykende            smoking    37  4.464286 -2.149929  -2.24   257.746331
# Viktigste             main    25  1.666667 -6.015873  -6.00   255.118839
# kakao                cocoa    35  2.673797 -3.686420  -3.74   245.101930
# serverte            served    43  4.424779 -2.181481  -2.26   240.712230
# kopper                cups    87  4.484305 -2.187566  -2.23   220.738775
# vafler             waffles    13  3.205128 -2.916667  -3.12   216.319529

# %% [markdown]
# # coll

# %% [markdown]
# # jaccard similarity
#
# compare over a range

# %%
rng = range(2,40,2)

# %% [markdown]
# # for collb

# %%
jaccard_scoresb = nb.frame({'ratio': {x:df_jaccard(collb[collb.freq > 20], 'reference', 'score', x) for x in rng}
                            }).transpose()

# %%
ax = jaccard_scoresb['ratio'].plot(title='compared to reference corpus');
ax.set_xlabel("Number of words")
ax.set_ylabel("Jaccard score")
# Out:
# Text(0, 0.5, 'Jaccard score')

# %% [markdown]
# # for coll

# %%
jaccard_scores = nb.frame({'ratio': {x:df_jaccard(coll, 'score', 'reference', x) for x in rng}     }).transpose()

# %%
ax = jaccard_scores['ratio'].plot(title='compared to reference corpus');
ax.set_xlabel("Number of words")
ax.set_ylabel("Jaccard score")

# %%
coll.loc[coll[coll.score > 4].index].sort_values(by='score', ascending=False)

# %%
coll.loc[coll[coll.reference> 30].index].sort_values(by='reference', ascending=False)

# %%
set(coll[coll.nb > 30].index) & set(coll[coll.score > 3.5].index)
